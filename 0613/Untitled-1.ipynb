# %%
import cv2
import matplotlib.pyplot as plt

image = cv2.imread(('./data/image01.png'))
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)

# %%
gamma = 3
img_corrected = cv2.pow(image/255.0, gamma)
img_corrected = cv2.cvt
