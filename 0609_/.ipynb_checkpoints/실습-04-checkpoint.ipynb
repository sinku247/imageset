# %% [markdown]
# # 최종적 실습을 위한 이미지 로드

# %%
import cv2
import matplotlib.pyplot as plt

# %%
sample_img = cv2.imread("./data/ex_image.png")
sample_logo = cv2.imread("./data/ex_image_logo.png")

img = cv2.cvtColor(sample_img, cv2.COLOR_BGR2RGB)
watermark = cv2.cvtColor(sample_logo, cv2.COLOR_BGR2RGB)

# 워터마크 이미지 리사이즈 200x200 
small_img = cv2.resize(watermark, (300,300))

# 선수 이미지 사진 리사이즈 1080 X 720 
resize_img = cv2.resize(img, (1080, 720))

plt.imshow(small_img)
plt.show()

plt.imshow(resize_img)
plt.show()

# %%
# 이미지 정보 가져오기 
import numpy as np

height, width, _ = small_img.shape
print("이미지 크기 >> " , height, width)

x_offset = 400 
y_offset = 170

roi = resize_img[y_offset:470, x_offset:700]
# roi = roi.astype(np.uint8)
plt.imshow(roi)
plt.show()
# Out:
# 이미지 크기 >>  300 300

# %% [markdown]
# # logo 이미지 회색조 버전 만들기

# %%
small_img_gray = cv2.cvtColor(small_img, cv2.COLOR_RGB2GRAY)

ret, mask = cv2.threshold(small_img_gray, 120, 255, cv2.THRESH_BINARY)
# mask = mask.astype(np.uint8)

print(mask.shape)

print(roi.shape)

# bg = cv2.bitwise_or(roi, roi, mask=mask)
bg = cv2.bitwise_or(roi,roi, mask = mask) 

plt.imshow(bg)
plt.show()
# Out:
# (300, 300)
# (300, 300, 3)
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Input In [4], in <cell line: 11>()
#       8 print(roi.shape)
#      10 # bg = cv2.bitwise_or(roi, roi, mask=mask)
# ---> 11 bg = cv2.bitwise_or(roi,mask,mask = mask)
#      13 plt.imshow(bg)
#      14 plt.show()
#
# error: OpenCV(4.5.4) /private/var/folders/b7/g6qfbypj0tq32j5_trjh516r0000gn/T/pip-req-build-f8yjfelj/opencv/modules/core/src/arithm.cpp:214: error: (-209:Sizes of input arguments do not match) The operation is neither 'array op array' (where arrays have the same size and type), nor 'array op scalar', nor 'scalar op array' in function 'binary_op'
