# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
def expend2square(pil_img, background_color):
    width, height = pil_img.size

    #정사각형
    if width == height:
        return pil_img
    
    #너비가 높이보다 큰 경우 처리 코드
    elif width > height:
        result = Image.new(pil_img.mode, (width, width), background_color)
        result.paste(pil_img, (0, (width - height) // 2))

        '''c
        .paste() 메서드는 result 이미지 객체에 pil_img 객체를 (0, (width - height) // 2) 위치에 붙여 넣음.
        따라서, pil_img 이미지는 result 이미지의 왼쪽 위 모서리에서부터 (0, (width - height) // 2) 좌표로 이동하여 붙여지게 됨.
        '''
        return result
    else :
        result = Image.new(pil_img.mode, (width, width), background_color)
        result.paste(pil_img, ((width - height) // 2, 0))
        return result
    
def resize_with_padding(pil_img, new_size, background_color):
    img = expend2square(pil_img, background_color)
    img = img.resize((new_size[0], new_size[1]), Image.ANTIALIAS)
    return img

img = Image.open('./download_image_data/0_apple.jpg')
img_new = resize_with_padding(img, (300,300), (0, 0, 0))
print(img_new.size)


plt.imshow(img_new)
plt.show()
# Out:
# (300, 300)
# C:\Users\maver\AppData\Local\Temp\ipykernel_16416\3955179702.py:25: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   img = img.resize((new_size[0], new_size[1]), Image.ANTIALIAS)
